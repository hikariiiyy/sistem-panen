# %% [markdown]
# <a href="https://colab.research.google.com/github/hikariiiyy/sistem-panen/blob/main/Nurmadani_sistem_panen_nomor_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Sistem Pencatatan Hasil Panen")

def laporan(data):
    print("===== LAPORAN HASIL PANEN =====")

    for komoditas, jumlah in data:
        print(f"Komoditas: {komoditas}")
        print(f"Jumlah: {jumlah} kg")
# Out:
# Sistem Pencatatan Hasil Panen
