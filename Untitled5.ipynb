# %% [markdown]
# <a href="https://colab.research.google.com/github/hikariiiyy/sistem-panen/blob/fitur-input/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Input Data Hasil Panen")
# Out:
# Input Data Hasil Panen
